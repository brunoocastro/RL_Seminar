# %%
# %pip install gymnasium
# %pip install "gymnasium[classic-control]"
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import gymnasium as gym

# %%
def policy(observation):
    """
    Simple policy example:
    - If angle < 0, action = 0
    - else, action = 1
    """
    angle = observation[2]
    if angle < 0:
        return 0
    else:
        return 1

# %%
env = gym.make("CartPole-v1", render_mode = "human")

observation, info = env.reset()

print("Observations: ", observation)
print("Info: ", info)

for episode in range(1000):
    env.render()
    action = policy(observation)
    
    observation, reward, truncated, terminated, info = env.step(action)
    print(f"[{episode}] Obs: {observation}")
    print(f"[{episode}] Reward: {reward}")

    # Considers done both if terminated (reached the goal or fail) or truncated (too many steps)
    done = terminated or truncated

    if done:
        if (truncated):
            print("Lose by time")
        else: 
            print("Win")
        observation, info = env.reset()

env.close()
# Out:
# Observations:  [ 0.02896778 -0.04097337 -0.03707207 -0.04656087]
# Info:  {}
# [0] Obs: [ 0.02814831 -0.23554467 -0.03800328  0.23419884]
# [0] Reward: 1.0
# [1] Obs: [ 0.02343741 -0.4301036  -0.03331931  0.51465625]
# [1] Reward: 1.0
# [2] Obs: [ 0.01483534 -0.62474084 -0.02302619  0.796656  ]
# [2] Reward: 1.0
# [3] Obs: [ 0.00234053 -0.81953937 -0.00709306  1.0820073 ]
# [3] Reward: 1.0
# [4] Obs: [-0.01405026 -1.014567    0.01454708  1.372456  ]
# [4] Reward: 1.0
# [5] Obs: [-0.0343416  -0.81962997  0.0419962   1.084358  ]
# [5] Reward: 1.0
# [6] Obs: [-0.0507342  -0.6250865   0.06368336  0.8051434 ]
# [6] Reward: 1.0
# [7] Obs: [-0.06323593 -0.4308927   0.07978623  0.5331534 ]
# [7] Reward: 1.0
# [8] Obs: [-0.07185379 -0.23697817  0.0904493   0.26663926]
# [8] Reward: 1.0
# [9] Obs: [-0.07659335 -0.04325572  0.09578209  0.00379926]
# [9] Reward: 1.0
# [10] Obs: [-0.07745846  0.15037139  0.09585807 -0.25719324]
# [10] Reward: 1.0
# ...

# %% [markdown]
# Ref: https://medium.com/ai%C2%B3-theory-practice-business/reinforcement-learning-part-1-a-brief-introduction-a53a849771cf
